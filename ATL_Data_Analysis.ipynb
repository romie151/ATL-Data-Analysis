# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Georgia_Counties.csv')

# %%
df
# Out:
#      OBJECTID  FacilityID      Name  GEOID10  MSA  ARC  FeatureID    TurnOut  \
# 0           1         NaN  Charlton    13049   No   No        NaN        NaN
# 1           2         NaN   Emanuel    13107   No   No        NaN        NaN
# 2           3         NaN     Wayne    13305   No   No        NaN        NaN
# 3           4         NaN  Ben Hill    13017   No   No        NaN        NaN
# 4           5         NaN   Appling    13001   No   No        NaN        NaN
# ..        ...         ...       ...      ...  ...  ...        ...        ...
# 154       157         NaN   Forsyth    13117  Yes   No        NaN        NaN
# 155       158         NaN  Gwinnett    13135  Yes  Yes        NaN        NaN
# 156       159         NaN   Clayton    13063  Yes  Yes        NaN        NaN
# 157       160         NaN    Fulton    13121  Yes  Yes        1.0  73.538781
# 158       161         NaN   Carroll    13045  Yes   No        NaN        NaN
#
#       ShapeSTArea  ShapeSTLength
# ...
